# %%
# importiamo la libreria Matplotlib

# %%
import matplotlib as mlp
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# se utilizziamo la shell di Python dobbiamo specificare anche il comando che segue per visualizzare i dati
# finché siamo su Jupyter non è necessario

# %%
# plt.show()

# %%
# quest’ultima riga di codice ci permette di visualizzare i grafici direttamente su Jupyter

# %%
# possiamo rappresentare una lista direttamente in questo modo

# %%
plt.plot([5,7,2,4])

# %%
plt.plot([5,7,2,4], [4,6,9,2], 'ro')

# %%
# creiamo due oggetti

x = [50, 70, 90, 65]
y = [129, 192, 163, 172]

# %%
x

# %%
y

# %%
plt.plot(x, y, linewidth = 4.0)

# %%
plt.plot(x, y, linewidth = 2.0, linestyle = '--')

# %%
plt.plot(x, y, linewidth = 1.0, ls = '-', marker = "o", markersize = 10)

# %%
plt.plot(x, y, linewidth = 1.0, ls = '-', marker = "o", markersize = 10, markerfacecolor = 'white')

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args: 'float | ArrayLike | str', scalex: 'bool' = True, scaley: 'bool' = True, data=None, **kwargs) -> 'list[Line2D]'
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
plt.plot()

# %%
# specifichiamo il titolo del grafico e il nome degli assi

# %%
plt.plot(x, y)
plt.title("TITLE")
plt.xlabel("Asse X")
plt.ylabel("Asse Y")
# Out:
# Text(0, 0.5, 'Asse Y')

# %%
plt.plot(x, y, color = "yellow")
plt.title("TITLE", color = "blue")
plt.xlabel("Asse X", color = "purple")
plt.ylabel("Asse Y", color = "green")
# Out:
# Text(0, 0.5, 'Asse Y')

# %%
plt.plot(x, y)
plt.title("TITLE", color = "blue")
plt.xlabel("Asse X", color = "purple")
plt.ylabel("Asse Y", color = "green")
plt.grid(True)
plt.legend(['Legend1'])

# %%
plt.plot(x, y)
plt.title("TITLE", color = "blue")
plt.xlabel("Asse X", color = "purple")
plt.ylabel("Asse Y", color = "green")
plt.grid(True)
plt.legend(['Legend1'], loc = 2)

# %% [markdown]
# Possibili posizioni della legenda
#
# 0
# 1 in alto a destra
# 2 in alto a sinistra
# 3 in basso a destra
# 4 in basso a sinistra
# 5 a destra
# 6 centrato a sinistra
# 7 centrato a destra
# 8 centrato basso
# 9 centrato alto
# 10 al centro

# %% [markdown]
# Codici dei colori
#
# b blu
# c ciano
# g verde
# m magenta
# r rosso
# y giallo
# k nero
# w bianco

# %%
plt.plot([1,2,3,4],[1,4,8,15],'b*')
plt.plot([1,3,5,7],[1,4,8,12],'g^')
plt.plot([1,2,3,5],[2,5,4,12],'ro')
plt.legend(['First','Second','Third'],loc=0)

# %%
# creiamo più sottografici

# %%
plt.subplot(2,2,1)
plt.plot([1,2,3,4],[1,4,8,15],'b*')

plt.subplot(2,2,2)
plt.plot([1,3,5,7],[1,4,8,12],'g^')

plt.subplot(2,2,3)
plt.plot([1,2,3,5],[2,5,4,12],'ro')

plt.subplot(2,2,4)
plt.plot([1,2,3,5],[2,5,4,12],'b')

# %%
# i numeri tra parentesi indicano numero di righe, numero di colonne e numero del grafico

# %%
plt.subplot(2,2,1)
plt.plot([1,2,3,4],[1,4,8,15],'b*')

plt.subplot(2,2,2)
plt.plot([1,3,5,7],[1,4,8,12],'g^')

plt.subplot(2,2,4)
plt.plot([1,2,3,5],[2,5,4,12],'ro')

plt.subplot(2,2,3)
plt.plot([1,2,3,5],[2,5,4,12],'b')

# %%
plt.subplot(1,2,1)
plt.plot([1,2,3,4],[1,4,8,15],'b*')

plt.subplot(1,2,2)
plt.plot([1,3,5,7],[1,4,8,12],'g^')

# %%
# piechart

# %%
x

# %%
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d3e17c9880>,
# ...
#  [Text(0.9253788759906099, 0.5947049149539254, ''),
#   Text(-0.39908849682508274, 1.0250504239801554, ''),
#   Text(-0.8899187180267097, -0.6465637441936393, ''),
#   Text(0.8104151864567372, -0.7437924613494629, '')])

# %%
col1 = ["yellow", "red", "purple", "orange"]

# %%
plt.pie(x, colors = col1)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d3e175b170>,
# ...
#  [Text(0.9253788759906099, 0.5947049149539254, ''),
#   Text(-0.39908849682508274, 1.0250504239801554, ''),
#   Text(-0.8899187180267097, -0.6465637441936393, ''),
#   Text(0.8104151864567372, -0.7437924613494629, '')])

# %%
lab1 = ['A','B','C','D']
plt.pie(x, colors = col1, labels = lab1)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d3e034ce30>,
# ...
#  [Text(0.9253788759906099, 0.5947049149539254, 'A'),
#   Text(-0.39908849682508274, 1.0250504239801554, 'B'),
#   Text(-0.8899187180267097, -0.6465637441936393, 'C'),
#   Text(0.8104151864567372, -0.7437924613494629, 'D')])

# %%
ex1 = [0.5,0,0,1]
lab1 = ['A','B','C','D']
plt.pie(x, colors = col1, labels = lab1, explode = ex1)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d3e037b6e0>,
# ...
#  [Text(1.3460056378045233, 0.8650253308420732, 'A'),
#   Text(-0.39908849682508274, 1.0250504239801554, 'B'),
#   Text(-0.8899187180267097, -0.6465637441936393, 'C'),
#   Text(1.547156265053771, -1.4199674262126107, 'D')])

# %%
# creiamo uno scatterplot

# %%
plt.scatter(x, y)

# %%
plt.bar(x, y)

# %%
plt.barh(x, y)
# Out:
# <BarContainer object of 4 artists>

# %%
import pandas as pd

# %%
import numpy as np

# %%
df1 = pd.DataFrame(np.random.rand(10 , 4), columns = ['var1', 'var2', 'var3', 'var4'])

# %%
df1
# Out:
#        var1      var2      var3      var4
# 0  0.389389  0.127278  0.054373  0.421709
# 1  0.601359  0.433088  0.324106  0.967117
# 2  0.167975  0.451060  0.208044  0.973921
# 3  0.508403  0.402246  0.093454  0.730700
# 4  0.261643  0.692247  0.385360  0.436561
# 5  0.759060  0.635572  0.491253  0.108022
# 6  0.213353  0.814543  0.805291  0.504581
# 7  0.393823  0.767740  0.086371  0.644702
# 8  0.617078  0.897187  0.010267  0.206791
# 9  0.198869  0.636311  0.495852  0.307032

# %%
df1.plot(kind = "bar")
# Out:
# <Axes: >

# %%
df1.plot(kind = "bar", stacked = True)
# Out:
# <Axes: >

# %%
print(df1)
# Out:
#        var1      var2      var3      var4
# 0  0.389389  0.127278  0.054373  0.421709
# 1  0.601359  0.433088  0.324106  0.967117
# 2  0.167975  0.451060  0.208044  0.973921
# 3  0.508403  0.402246  0.093454  0.730700
# 4  0.261643  0.692247  0.385360  0.436561
# 5  0.759060  0.635572  0.491253  0.108022
# 6  0.213353  0.814543  0.805291  0.504581
# 7  0.393823  0.767740  0.086371  0.644702
# 8  0.617078  0.897187  0.010267  0.206791
# 9  0.198869  0.636311  0.495852  0.307032

# %%
df1.hist()
# Out:
# array([[<Axes: title={'center': 'var1'}>,
#         <Axes: title={'center': 'var2'}>],
#        [<Axes: title={'center': 'var3'}>,
#         <Axes: title={'center': 'var4'}>]], dtype=object)

# %%
df1['var1'].hist()
# Out:
# <Axes: >

# %%
df1.loc[1].hist()
# Out:
# <Axes: >

# %%
df1.boxplot(return_type = "axes")
# Out:
# <Axes: >

# %%
df1.plot(kind = "area")
# Out:
# <Axes: >

# %%
df1.plot(kind = "area", color = col1)
# Out:
# <Axes: >

# %%
df1.plot(kind = "area", stacked = False)
# Out:
# <Axes: >

# %%
df1.plot(kind = "scatter", x = "var3", y = "var4")

# salviamo l'immagine nella cartella di lavoro

plt.savefig('graph1.png')

# %%
df1.plot(kind = "scatter", x = "var3", y = "var4")

plt.savefig('graph1.png', dpi = 600)

# %%
# stili per modificare un grafico

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# come applichiamo uno stile?

# %%
plt.style.use('dark_background')
df1.plot(kind = "area")

# %%
plt.style.use('seaborn-darkgrid')
df1.plot(kind = "area")

# %%
plt.style.use('ggplot')
df1.plot(kind = "area")

# %%
# creiamo ancora due oggetti casuali con numpy e li rappresentiamo graficamente

# %%
df2 = np.random.randn(100)

# %%
df3 = np.random.randn(100)

# %%
plt.hist(df2)

# %%
plt.hist(df3)

# %%
# adesso mettiamo a confronto i due dataset in uno stesso grafico

# %%
plt.hist(df2, color = "red", alpha = 0.3, bins = 15)
plt.hist(df3, color = "blue", alpha = 0.4, bins = 15)
